# %% [markdown]
# # Quick Investigation on Data

# %%
#Import libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Read data
data_set = pd.read_csv("data/GrandMaster_Ranked_Games.csv")
data_set.head()
# Out:
#        gameId  gameDuraton  blueWins  blueFirstBlood  blueFirstTower  \
# 0  4241678498         2098         0               0               0
# 1  4233222221         1686         0               0               1
# 2  4233113995         1588         1               1               1
# 3  4229230455         1126         1               0               1
# 4  4228244819         1262         1               0               0
#
#    blueFirstBaron  blueFirstDragon  blueFirstInhibitor  blueDragonKills  \
# 0               1                1                   0                1
# 1               0                0                   0                0
# 2               1                0                   1                2
# 3               0                1                   0                1
# 4               0                1                   1                3
#
#    blueBaronKills  ...  redAssist  redChampionDamageDealt  redTotalGold  \
# 0               1  ...         72                  125866         70528
# 1               0  ...         59                   78424         58032
# 2               1  ...         30                   62134         47408
# 3               0  ...         13                   32999         32064
# 4               0  ...          5                   35272         35372
#
#    redTotalMinionKills  redTotalLevel  redAvgLevel  redJungleMinionKills  \
# 0                  832             84         16.8                   205
# 1                  640             73         14.6                   214
# 2                  608             63         12.6                   133
# 3                  461             53         10.6                    92
# 4                  506             54         10.8                   113
#
#    redKillingSpree  redTotalHeal  redObjectDamageDealt
# 0                9         65312                 88202
# 1                5         31415                 61040
# 2                5         27846                 32107
# 3                3         23511                 10775
# 4                2         17891                 24158
#
# [5 rows x 50 columns]

# %%
#About data
data_set.describe()
data_set.shape
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65896 entries, 0 to 65895
# Data columns (total 50 columns):
# gameId                     65896 non-null int64
# gameDuraton                65896 non-null int64
# blueWins                   65896 non-null int64
# blueFirstBlood             65896 non-null int64
# blueFirstTower             65896 non-null int64
# blueFirstBaron             65896 non-null int64
# blueFirstDragon            65896 non-null int64
# blueFirstInhibitor         65896 non-null int64
# blueDragonKills            65896 non-null int64
# blueBaronKills             65896 non-null int64
# blueTowerKills             65896 non-null int64
# blueInhibitorKills         65896 non-null int64
# blueWardPlaced             65896 non-null int64
# blueWardkills              65896 non-null int64
# blueKills                  65896 non-null int64
# blueDeath                  65896 non-null int64
# blueAssist                 65896 non-null int64
# blueChampionDamageDealt    65896 non-null int64
# blueTotalGold              65896 non-null int64
# blueTotalMinionKills       65896 non-null int64
# blueTotalLevel             65896 non-null int64
# blueAvgLevel               65896 non-null float64
# blueJungleMinionKills      65896 non-null int64
# blueKillingSpree           65896 non-null int64
# blueTotalHeal              65896 non-null int64
# blueObjectDamageDealt      65896 non-null int64
# redWins                    65896 non-null int64
# redFirstBlood              65896 non-null int64
# redFirstTower              65896 non-null int64
# redFirstBaron              65896 non-null int64
# redFirstDragon             65896 non-null int64
# redFirstInhibitor          65896 non-null int64
# redDragonKills             65896 non-null int64
# redBaronKills              65896 non-null int64
# redTowerKills              65896 non-null int64
# redInhibitorKills          65896 non-null int64
# redWardPlaced              65896 non-null int64
# redWardkills               65896 non-null int64
# redKills                   65896 non-null int64
# redDeath                   65896 non-null int64
# redAssist                  65896 non-null int64
# redChampionDamageDealt     65896 non-null int64
# redTotalGold               65896 non-null int64
# redTotalMinionKills        65896 non-null int64
# redTotalLevel              65896 non-null int64
# redAvgLevel                65896 non-null float64
# redJungleMinionKills       65896 non-null int64
# redKillingSpree            65896 non-null int64
# redTotalHeal               65896 non-null int64
# redObjectDamageDealt       65896 non-null int64
# dtypes: float64(2), int64(48)
# memory usage: 25.1 MB

# %% [markdown]
# #  Co-relation Matrix

# %%
#Represented with heatmap:
plt.figure(figsize = (30,30))
sns.heatmap(data_set.corr(),annot = True,cmap = plt.cm.Purples)
plt.show()

# %%
#Irrelevant informations are GAME ID and GAME DURATION.
#Removing them with red wins because we have already blue wins. There are no tie in this game.
data_set = data_set.drop(['gameId','gameDuraton','redWins'],axis = 1)

# %%
#Co-relation matrix revisited
plt.figure(figsize = (30,30))
sns.heatmap(data_set.corr(),annot = True,cmap = plt.cm.Blues)
plt.show()

# %% [markdown]
# # Exploratory Data Analysis

# %%
data_set
data_set.columns
# Out:
# Index(['blueWins', 'blueFirstBlood', 'blueFirstTower', 'blueFirstBaron',
#        'blueFirstDragon', 'blueFirstInhibitor', 'blueDragonKills',
#        'blueBaronKills', 'blueTowerKills', 'blueInhibitorKills',
#        'blueWardPlaced', 'blueWardkills', 'blueKills', 'blueDeath',
#        'blueAssist', 'blueChampionDamageDealt', 'blueTotalGold',
#        'blueTotalMinionKills', 'blueTotalLevel', 'blueAvgLevel',
#        'blueJungleMinionKills', 'blueKillingSpree', 'blueTotalHeal',
#        'blueObjectDamageDealt', 'redFirstBlood', 'redFirstTower',
#        'redFirstBaron', 'redFirstDragon', 'redFirstInhibitor',
#        'redDragonKills', 'redBaronKills', 'redTowerKills', 'redInhibitorKills',
#        'redWardPlaced', 'redWardkills', 'redKills', 'redDeath', 'redAssist',
#        'redChampionDamageDealt', 'redTotalGold', 'redTotalMinionKills',
#        'redTotalLevel', 'redAvgLevel', 'redJungleMinionKills',
#        'redKillingSpree', 'redTotalHeal', 'redObjectDamageDealt'],
#       dtype='object')

# %% [markdown]
# # Data Preprocessing

# %%
y = data_set.iloc[:,0].values #win class
x = data_set.iloc[:,1:].values #other attributes seperated

# %%
#Preparing train and test data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.3,stratify=y)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
'''#Double Cross Validation in order to find optimal n_estimators and max_features that results with useful accuracy. 

from sklearn.model_selection import KFold
from sklearn import tree
import matplotlib.pyplot as plt

# manual nested cross-validation for random forest on a classification dataset
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# configure the cross-validation procedure
cv_outer = KFold(n_splits=10, shuffle=True, random_state=1)
# enumerate splits
outer_results = list()
for train_ix, test_ix in cv_outer.split(x):
	# split data
	X_train, X_test = x[train_ix, :], x[test_ix, :]
	y_train, y_test = y[train_ix], y[test_ix]
	# configure the cross-validation procedure
	cv_inner = KFold(n_splits=3, shuffle=True, random_state=1)
	# define the model
	model = RandomForestClassifier(random_state=1)
	# define search space
	space = dict()
	space['n_estimators'] = [100, 400, 1000]
	space['max_features'] = [4, 6, 10]
	# define search
	search = GridSearchCV(model, space, scoring='accuracy', cv=cv_inner, refit=True)
	# execute search
	result = search.fit(X_train, y_train)
	# get the best performing model fit on the whole training set
	best_model = result.best_estimator_
	# evaluate model on the hold out dataset
	yhat = best_model.predict(X_test)
	# evaluate the model
	acc = accuracy_score(y_test, yhat)
	# store the result
	outer_results.append(acc)
	# report progress
	print('>acc=%.3f, est=%.3f, cfg=%s' % (acc, result.best_score_, result.best_params_))
# summarize the estimated performance of the model
print('Accuracy: %.3f (%.3f)' % (mean(outer_results), std(outer_results)))'''
# Out:
# "#Double Cross Validation in order to find optimal n_estimators and max_features that results with useful accuracy. \n\nfrom sklearn.model_selection import KFold\nfrom sklearn import tree\nimport matplotlib.pyplot as plt\n\n# manual nested cross-validation for random forest on a classification dataset\nfrom numpy import mean\nfrom numpy import std\nfrom sklearn.datasets import make_classification\nfrom sklearn.model_selection import KFold\nfrom sklearn.model_selection import GridSearchCV\nfrom sklearn.ensemble import RandomForestClassifier\nfrom sklearn.metrics import accuracy_score\n\n# configure the cross-validation procedure\ncv_outer = KFold(n_splits=10, shuffle=True, random_state=1)\n# enumerate splits\nouter_results = list()\nfor train_ix, test_ix in cv_outer.split(x):\n\t# split data\n\tX_train, X_test = x[train_ix, :], x[test_ix, :]\n\ty_train, y_test = y[train_ix], y[test_ix]\n\t# configure the cross-validation procedure\n\tcv_inner = KFold(n_splits=3, shuffle=True, random_state=1)\n\t# define the model\n\tmodel = RandomForestClassifier(random_state=1)\n\t# define search space\n\tspace = dict()\n\tspace['n_estimators'] = [100, 400, 1000]\n\tspace['max_features'] = [4, 6, 10]\n\t# define search\n\tsearch = GridSearchCV(model, space, scoring='accuracy', cv=cv_inner, refit=True)\n\t# execute search\n\tresult = search.fit(X_train, y_train)\n\t# get the best performing model fit on the whole training set\n\tbest_model = result.best_estimator_\n\t# evaluate model on the hold out dataset\n\tyhat = best_model.predict(X_test)\n\t# evaluate the model\n\tacc = accuracy_score(y_test, yhat)\n\t# store the result\n\touter_results.append(acc)\n\t# report progress\n\tprint('>acc=%.3f, est=%.3f, cfg=%s' % (acc, result.best_score_, result.best_params_))\n# summarize the estimated performance of the model\nprint('Accuracy: %.3f (%.3f)' % (mean(outer_results), std(outer_results)))"

# %% [markdown]
# # Modal Selection - XGboost Classifier

# %%
from xgboost import XGBClassifier
from sklearn.metrics import confusion_matrix,accuracy_score

classifier = XGBClassifier(n_estimators = 100,learning_rate = 0.3)
classifier.fit(x_train,y_train, eval_set=[(x_train,y_train),(x_test,y_test)])
y_pred = classifier.predict(x_test)
# Out:
# [0]	validation_0-error:0.02380	validation_1-error:0.02731
# [1]	validation_0-error:0.02012	validation_1-error:0.02347
# [2]	validation_0-error:0.01854	validation_1-error:0.02190
# [3]	validation_0-error:0.01674	validation_1-error:0.02008
# [4]	validation_0-error:0.01515	validation_1-error:0.01902
# [5]	validation_0-error:0.01420	validation_1-error:0.01791
# [6]	validation_0-error:0.01322	validation_1-error:0.01700
# [7]	validation_0-error:0.01210	validation_1-error:0.01609
# [8]	validation_0-error:0.01082	validation_1-error:0.01442
# [9]	validation_0-error:0.00969	validation_1-error:0.01351
# [10]	validation_0-error:0.00921	validation_1-error:0.01351
# [11]	validation_0-error:0.00878	validation_1-error:0.01270
# [12]	validation_0-error:0.00850	validation_1-error:0.01244
# [13]	validation_0-error:0.00833	validation_1-error:0.01239
# [14]	validation_0-error:0.00774	validation_1-error:0.01219
# [15]	validation_0-error:0.00750	validation_1-error:0.01189
# [16]	validation_0-error:0.00705	validation_1-error:0.01199
# [17]	validation_0-error:0.00661	validation_1-error:0.01153
# [18]	validation_0-error:0.00613	validation_1-error:0.01123
# [19]	validation_0-error:0.00581	validation_1-error:0.01118
# [20]	validation_0-error:0.00538	validation_1-error:0.01088
# [21]	validation_0-error:0.00492	validation_1-error:0.01062
# [22]	validation_0-error:0.00442	validation_1-error:0.01037
# [23]	validation_0-error:0.00388	validation_1-error:0.01062
# [24]	validation_0-error:0.00382	validation_1-error:0.01057
# [25]	validation_0-error:0.00356	validation_1-error:0.01022
# [26]	validation_0-error:0.00334	validation_1-error:0.01032
# [27]	validation_0-error:0.00316	validation_1-error:0.01012
# [28]	validation_0-error:0.00293	validation_1-error:0.01032
# [29]	validation_0-error:0.00267	validation_1-error:0.01012
# [30]	validation_0-error:0.00256	validation_1-error:0.01002
# [31]	validation_0-error:0.00251	validation_1-error:0.00971
# [32]	validation_0-error:0.00223	validation_1-error:0.01002
# [33]	validation_0-error:0.00202	validation_1-error:0.01002
# [34]	validation_0-error:0.00180	validation_1-error:0.00996
# [35]	validation_0-error:0.00171	validation_1-error:0.00976
# [36]	validation_0-error:0.00158	validation_1-error:0.00971
# [37]	validation_0-error:0.00152	validation_1-error:0.00971
# [38]	validation_0-error:0.00143	validation_1-error:0.00971
# [39]	validation_0-error:0.00132	validation_1-error:0.00981
# [40]	validation_0-error:0.00126	validation_1-error:0.00971
# [41]	validation_0-error:0.00115	validation_1-error:0.00981
# [42]	validation_0-error:0.00106	validation_1-error:0.00986
# [43]	validation_0-error:0.00104	validation_1-error:0.00986
# [44]	validation_0-error:0.00098	validation_1-error:0.00971
# [45]	validation_0-error:0.00093	validation_1-error:0.00961
# [46]	validation_0-error:0.00085	validation_1-error:0.00941
# [47]	validation_0-error:0.00082	validation_1-error:0.00956
# [48]	validation_0-error:0.00076	validation_1-error:0.00956
# [49]	validation_0-error:0.00076	validation_1-error:0.00966
# [50]	validation_0-error:0.00074	validation_1-error:0.00951
# [51]	validation_0-error:0.00065	validation_1-error:0.00966
# [52]	validation_0-error:0.00059	validation_1-error:0.00961
# [53]	validation_0-error:0.00059	validation_1-error:0.00956
# [54]	validation_0-error:0.00059	validation_1-error:0.00946
# [55]	validation_0-error:0.00059	validation_1-error:0.00941
# [56]	validation_0-error:0.00059	validation_1-error:0.00941
# [57]	validation_0-error:0.00052	validation_1-error:0.00966
# [58]	validation_0-error:0.00048	validation_1-error:0.00956
# [59]	validation_0-error:0.00043	validation_1-error:0.00961
# [60]	validation_0-error:0.00039	validation_1-error:0.00946
# [61]	validation_0-error:0.00032	validation_1-error:0.00926
# [62]	validation_0-error:0.00028	validation_1-error:0.00936
# [63]	validation_0-error:0.00030	validation_1-error:0.00936
# [64]	validation_0-error:0.00030	validation_1-error:0.00936
# [65]	validation_0-error:0.00028	validation_1-error:0.00931
# [66]	validation_0-error:0.00028	validation_1-error:0.00931
# [67]	validation_0-error:0.00022	validation_1-error:0.00916
# [68]	validation_0-error:0.00022	validation_1-error:0.00931
# [69]	validation_0-error:0.00017	validation_1-error:0.00931
# [70]	validation_0-error:0.00017	validation_1-error:0.00936
# [71]	validation_0-error:0.00017	validation_1-error:0.00936
# [72]	validation_0-error:0.00017	validation_1-error:0.00926
# [73]	validation_0-error:0.00015	validation_1-error:0.00906
# [74]	validation_0-error:0.00015	validation_1-error:0.00911
# [75]	validation_0-error:0.00013	validation_1-error:0.00921
# [76]	validation_0-error:0.00013	validation_1-error:0.00921
# [77]	validation_0-error:0.00013	validation_1-error:0.00906
# [78]	validation_0-error:0.00013	validation_1-error:0.00906
# [79]	validation_0-error:0.00013	validation_1-error:0.00906
# [80]	validation_0-error:0.00013	validation_1-error:0.00921
# [81]	validation_0-error:0.00013	validation_1-error:0.00916
# [82]	validation_0-error:0.00013	validation_1-error:0.00890
# [83]	validation_0-error:0.00013	validation_1-error:0.00895
# [84]	validation_0-error:0.00013	validation_1-error:0.00890
# [85]	validation_0-error:0.00013	validation_1-error:0.00895
# [86]	validation_0-error:0.00013	validation_1-error:0.00875
# [87]	validation_0-error:0.00013	validation_1-error:0.00875
# [88]	validation_0-error:0.00011	validation_1-error:0.00875
# [89]	validation_0-error:0.00009	validation_1-error:0.00875
# [90]	validation_0-error:0.00009	validation_1-error:0.00850
# [91]	validation_0-error:0.00009	validation_1-error:0.00880
# [92]	validation_0-error:0.00009	validation_1-error:0.00875
# [93]	validation_0-error:0.00009	validation_1-error:0.00870
# [94]	validation_0-error:0.00009	validation_1-error:0.00850
# [95]	validation_0-error:0.00009	validation_1-error:0.00860
# [96]	validation_0-error:0.00009	validation_1-error:0.00865
# [97]	validation_0-error:0.00009	validation_1-error:0.00880
# [98]	validation_0-error:0.00009	validation_1-error:0.00875
# [99]	validation_0-error:0.00009	validation_1-error:0.00865

# %% [markdown]
# # Metrics #1-1

# %%
cm = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)

print(cm,"\n accuracy:",accuracy)
# Out:
# [[9880   91]
#  [  80 9718]]
#  accuracy: 0.9913500935808589

# %% [markdown]
# # Modal Selection - Decision Tree Classifier

# %%
from sklearn import tree
import matplotlib.pyplot as plt

clf = tree.DecisionTreeClassifier(criterion = "gini", min_samples_split=3000, max_features=4)
clf = clf.fit(x_train,y_train)
y_pred2 = clf.predict(x_test)

# %% [markdown]
# # Metrics #1-2

# %%
cm2 = confusion_matrix(y_test, y_pred2)
accuracy2 = accuracy_score(y_test, y_pred2)
print(cm2,"\n accuracy:",accuracy2)
# Out:
# [[9278  693]
#  [ 699 9099]]
#  accuracy: 0.9295867266933077

# %% [markdown]
# # Visualization of XGB Tree and Decision Tree 1

# %%
#XGB Tree as .png saved
import xgboost as xgb

format = 'png' #You should try the 'svg'

image = xgb.to_graphviz(classifier)

#Set a different dpi (work only if format == 'png')
image.graph_attr = {'dpi':'400'}

image.render('original-GrandMaster-XGB-1', format = format)
# Out:
# 'original-GrandMaster-XGB-1.png'

# %%
#Decision Tree as you can see down below and saved as .png
tree_plot = plt.figure(figsize=(20,20))
tree.plot_tree(clf)
plt.show()

from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus
import pandas as pd
import graphviz

dot_data = export_graphviz(clf, out_file=None,filled=True, rounded=True, special_characters=True ,class_names=['0','1'])
graph = graphviz.Source(dot_data)

graph.render(filename="original-GrandMaster-Decision-1", format="png")
# Out:
# C:\Users\alper\Anaconda3\lib\site-packages\sklearn\externals\six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)
# 'original-GrandMaster-Decision-1.png'

# %% [markdown]
# # Dimensionality Reduction by PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 1)
reduction = pca.fit_transform(x_train)
reduction_test = pca.transform(x_test)
print(pca.explained_variance_ratio_)
# Out:
# [0.35479461]

# %%
data_reduced = pd.DataFrame(data = reduction,columns = ['pc1'])
data_reduced
# Out:
#              pc1
# 0      -1.409211
# 1       2.111634
# 2       1.322881
# 3      -0.461215
# 4       0.093275
# 5       7.200124
# 6      -3.759528
# 7      -0.882184
# 8       1.449048
# 9       5.508522
# 10      1.851283
# 11     -5.372883
# 12     -3.743918
# 13     -4.305973
# 14     -5.777788
# 15      4.341654
# 16     -5.372042
# 17      0.512598
# 18      2.349958
# 19      0.746302
# 20     -2.140908
# 21     -0.899926
# 22     -2.223700
# 23     -6.525169
# 24      0.484074
# 25     -5.441104
# 26     -6.434564
# 27      7.189389
# 28     -2.907569
# 29     -5.840559
# ...          ...
# 46097  -2.637819
# 46098   6.140337
# 46099  -4.243848
# 46100   3.344865
# 46101  -2.955066
# 46102   5.272202
# 46103  -5.239783
# 46104  -3.631491
# 46105   6.044187
# 46106 -11.391343
# 46107   2.806369
# 46108   6.825444
# 46109   5.302423
# 46110   5.651880
# 46111  -2.396369
# 46112  -3.185667
# 46113  -1.207762
# 46114   1.958977
# 46115   0.025578
# 46116  -5.140997
# 46117   3.033881
# 46118   6.967507
# 46119   1.132154
# 46120  -1.192291
# 46121  -0.114985
# 46122 -11.347007
# 46123  -2.359223
# 46124   6.204684
# 46125   4.241163
# 46126   0.783910
#
# [46127 rows x 1 columns]

# %%
reduction_test
# Out:
# array([[-3.38656689],
#        [-6.54734726],
#        [-6.19468581],
#        ...,
#        [ 1.98209882],
#        [ 3.43825384],
#        [-1.48222876]])

# %%
#Preparing PC1 to put in XGB again
x_reduced = data_reduced.iloc[:,:].values

# %% [markdown]
# # PCA XGB Tree

# %%
#Fitting XGB Classifier
from xgboost import XGBClassifier
reduced_class = XGBClassifier(n_estimators = 100,learning_rate = 0.1)
reduced_class.fit(x_reduced,y_train)
y_reduced_pred = reduced_class.predict(reduction_test)

# %% [markdown]
# # Metrics #2-1

# %%
from sklearn.metrics import confusion_matrix,accuracy_score

cm = confusion_matrix(y_test, y_reduced_pred)
accuracy = accuracy_score(y_test, y_reduced_pred)
print(cm,"\n accuracy:",accuracy)
# Out:
# [[5801 4170]
#  [5627 4171]]
#  accuracy: 0.5044261217057009

# %% [markdown]
# # PCA Decision Tree

# %%
#Fitting Decision Tree Classifier
clf2 = tree.DecisionTreeClassifier(criterion = "gini", min_samples_split=3000)
clf2 = clf2.fit(x_reduced,y_train)
y_reduced_pred2 = clf2.predict(reduction_test)

# %%
cm2 = confusion_matrix(y_test, y_reduced_pred2)
accuracy2 = accuracy_score(y_test, y_reduced_pred2)
print(cm2,"\n accuracy:",accuracy2)
# Out:
# [[5605 4366]
#  [5537 4261]]
#  accuracy: 0.49906419141079467

# %% [markdown]
# # Visualization of XGB Tree and Decision Tree 2

# %%
#XGB Tree as .png saved
import xgboost as xgb

format = 'png' #You should try the 'svg'

image = xgb.to_graphviz(reduced_class)

#Set a different dpi (work only if format == 'png')
image.graph_attr = {'dpi':'400'}

image.render('original-GrandMaster-XGB-2', format = format)
# Out:
# 'original-GrandMaster-XGB-2.png'

# %%
#Decision Tree as you can see down below and saved as .png
tree_plot = plt.figure(figsize=(20,20))
tree.plot_tree(clf2)
plt.show()

from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus
import pandas as pd
import graphviz

dot_data = export_graphviz(clf2, out_file=None,filled=True, rounded=True, special_characters=True ,class_names=['0','1'])
graph = graphviz.Source(dot_data)

graph.render(filename="original-GrandMaster-Decision-2", format="png")
# Out:
# 'original-GrandMaster-Decision-2.png'
